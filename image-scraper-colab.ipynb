# %% [markdown]
# ## Image Scraper

# %%
from google.colab import drive
drive.mount('/content/drive')
install_root = "/content/drive/MyDrive/ai"
# %mkdir -p $install_root
# %cd $install_root

Ngrok_token = "" #@param {type:"string"}

import os
if not os.path.exists(f"{install_root}/image-scraper"):
    # !git clone https://github.com/brenton-thomas/Image-Scraper-Colab image-scraper

# %cd image-scraper
# !python
